# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser
import pandas as pd
import os
import time
import requests

# %%
executable_path = {'executable_path': 'chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = "https://nces.ed.gov/programs/digest/d19/tables/dt19_203.65.asp"
browser.visit(url)

# %%
 html = browser.html

# %%
tables = pd.read_html(url)

df = tables[3]

df.columns = ['school-Yer', 'All Grades', 'Total','Prekindergarden', 'kindergarden', 'first_grade', 'second_grade', 'third_grade','forth_grade','fifth_grade', 'sixth_grade','seventh_grade', 'eighth_grade','ungraded','total', 'ninth_grade', 'tenth_grade', 'eleventh_grade', 'twelvth_grade','ungraded']
html_table = df.to_html(table_id="html_tbl_css",justify='left',index=False)
data = df.to_dict(orient='records')  
df.head(10)
# Out:
# C:\Users\whitn\anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   import sys
#                       school-Yer  All Grades    Total  Prekindergarden  \
# 0                           1999         NaN      NaN              NaN
# 1                          Total     46857.0  33486.0            751.0
# 2                          White     29035.0  20327.0            354.0
# 3                          Black      8066.0   5952.0            181.0
# 4                       Hispanic      7327.0   5512.0            180.0
# 5         Asian/Pacific Islander      1887.0   1303.0             27.0
# 6  American Indian/Alaska Native       542.0    391.0              9.0
# 7                            NaN         NaN      NaN              NaN
# 8                           2001         NaN      NaN              NaN
# 9                          Total     47672.0  33936.0            865.0
#
# ...

# %%
df.dropna(subset=["school-Yer"],inplace=True)
df.head(5)
# Out:
#   school-Yer  All Grades    Total  Prekindergarden  kindergarden  first_grade  \
# 0       1999         NaN      NaN              NaN           NaN          NaN
# 1      Total     46857.0  33486.0            751.0        3397.0       3684.0
# 2      White     29035.0  20327.0            354.0        2010.0       2159.0
# 3      Black      8066.0   5952.0            181.0         590.0        679.0
# 4   Hispanic      7327.0   5512.0            180.0         627.0        662.0
#
#    second_grade  third_grade  forth_grade  fifth_grade  sixth_grade  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1        3656.0       3691.0       3686.0       3604.0       3564.0
# 2        2175.0       2219.0       2261.0       2240.0       2231.0
# 3         660.0        666.0        644.0        622.0        610.0
# 4         636.0        620.0        594.0        556.0        538.0
#
#    seventh_grade  eighth_grade  ungraded    total  ninth_grade  tenth_grade  \
# ...

# %%
cleaned_data = df.drop(['All Grades', 'Total', 'ungraded', 'total', 'ungraded'], axis=1)
cleaned_data.head(10)
# Out:
#                        school-Yer  Prekindergarden  kindergarden  first_grade  \
# 0                            1999              NaN           NaN          NaN
# 1                           Total            751.0        3397.0       3684.0
# 2                           White            354.0        2010.0       2159.0
# 3                           Black            181.0         590.0        679.0
# 4                        Hispanic            180.0         627.0        662.0
# 5          Asian/Pacific Islander             27.0         132.0        142.0
# 6   American Indian/Alaska Native              9.0          39.0         43.0
# 8                            2001              NaN           NaN          NaN
# 9                           Total            865.0        3379.0       3614.0
# 10                          White            404.0        1955.0       2073.0
#
#     second_grade  third_grade  forth_grade  fifth_grade  sixth_grade  \
# ...

# %%
csv_data=cleaned_data.to_csv
csv_data('ETL.csv')
