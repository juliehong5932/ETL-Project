# %%
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd

# %%
def init_browser():
    # @NOTE: Replace the path with your actual path to the chromedriver
    executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
    return Browser("chrome", **executable_path, headless=False)

# %%
def scrape_nations_report_card():
    browser = init_browser()
    url = "https://www.nationsreportcard.gov/"
    
def scrape():
    browser = init_browser()
    data_dict = {}

    url = "https://raleigh.craigslist.org/search/hhh?max_price=1500&availabilityMode=0"
    browser.visit(url)

    html = browser.html
    soup = BeautifulSoup(html, "html.parser")

    return data_dict

# %%
# Alternative 
#browser = init_browser()

# %%
#url = "https://www.nationsreportcard.gov/"

# %%
#browser.visit(url)

# %%
# find button name=tab2 and click it
# element = browser.find_by_id('gradeid').first
customize_data_button = browser.find_by_name('tab2').first
customize_data_button.click()

# %%
# Select Grade 8 you can choose the gradte 
element = browser.find_by_id('gradeid').first
try:
    element.select('Grade 8')
except Exception:
     element.select(2)
# find_h=browser.find_by_css('div[class="medium-widget success-story-category last"]:nth-child(2)')

# %%
# select subject = Math
subid = browser.find_by_id('subjectid').first
subid.select(4)

# %%
# select Juridiction: National --> Tried the State one but does not have the 
subid = browser.find_by_id('jurdid').first
subid.select("National")

# %%
# include school type data 
# 5 = "Type of School"
subid = browser.find_by_id('variid').first
subid.select(5)

# %%
# Click the create table link

# Set cookie to accept Terms of Services
#TOS_NCE_Accepted = TOS_NCE123
browser.cookies.add({'TOS_NCE_Accepted': 'TOS_NCE123'})
browser.click_link_by_text('create table')

# %%
# Scrape the page
# Get the table HTML
tables = browser.find_by_tag('table')
data_table = tables[0]
print(data_table.outer_html)
#print(soup.prettify())
# Out:
# <table class="nrc-rteTable-default report-card" width="100%" cellspacing="0">
#                      <thead>
#                         <tr>
#                            <td></td>
#                            <th scope="colgroup" colspan="3" id="rt"><span>PERCENTAGE OF STUDENTS AT OR ABOVE <em>NAEP Proficient</em></span></th>
#                         </tr>
#                         <tr>
#                            <td>​</td>
#                            <th scope="col" class="nrc-rteTable-default" id="g4">Grade 4​</th>
#                            <th scope="col" class="nrc-rteTable-default" id="g8">​Grade 8</th>
#                            <th scope="col" class="nrc-rteTable-default" id="g12">​Grade 12</th>
#                         </tr>
#                      </thead>
#                      <tbody>
#                         <tr>
# ...

# %%
 find_table=browser.find_by_css('table[class_="k-grid data-table-grid"]')

# %%
#print(find_table[0])

# %%
# get the table HTML
# outer_html includes the surrounding <table> tags
table_html = data_table.outer_html
print(table_html)
# Out:
# <table class="nrc-rteTable-default report-card" width="100%" cellspacing="0">
#                      <thead>
#                         <tr>
#                            <td></td>
#                            <th scope="colgroup" colspan="3" id="rt"><span>PERCENTAGE OF STUDENTS AT OR ABOVE <em>NAEP Proficient</em></span></th>
#                         </tr>
#                         <tr>
#                            <td>​</td>
#                            <th scope="col" class="nrc-rteTable-default" id="g4">Grade 4​</th>
#                            <th scope="col" class="nrc-rteTable-default" id="g8">​Grade 8</th>
#                            <th scope="col" class="nrc-rteTable-default" id="g12">​Grade 12</th>
#                         </tr>
#                      </thead>
#                      <tbody>
#                         <tr>
# ...

# %%
# load table html in pandas dataframe
df = pd.read_html(table_html)

# %%
# HMMMM NEED HELP
# Out:
# [                    Unnamed: 0_level_0  \
#                                       ​
#  0                         ​Arts: Music
#  1                   ​Arts: Visual Arts
#  2                              ​Civics
#  3                            Economics
#  4                           ​Geography
#  5                         ​Mathematics
#  6                             ​Reading
#  7                             ​Science
#  8   ​Technology & Engineering Literacy
#  9                        ​U.S. History
#  10                             Writing
#
#     PERCENTAGE OF STUDENTS AT OR ABOVE NAEP Proficient  \
#                                               Grade 4​
#  0                                  Data not available
#  1                                  Data not available
#  2   Donut chart representing the stat for At or ab...
#  3                                  Data not available
#  4   Donut chart representing the stat for At or ab...
# ...

# %%
test.rename(columns={"Grade_4": "Grade 4", "Grade_8": "Grade 8"})
test = test
test
# Out:
#                     Unnamed: 0_level_0  \
#                                      ​
# 0                         ​Arts: Music
# 1                   ​Arts: Visual Arts
# 2                              ​Civics
# 3                            Economics
# 4                           ​Geography
# 5                         ​Mathematics
# 6                             ​Reading
# 7                             ​Science
# 8   ​Technology & Engineering Literacy
# 9                        ​U.S. History
# 10                             Writing
#
#    PERCENTAGE OF STUDENTS AT OR ABOVE NAEP Proficient  \
#                                              Grade 4​
# 0                                  Data not available
# 1                                  Data not available
# 2   Donut chart representing the stat for At or ab...
# 3                                  Data not available
# 4   Donut chart representing the stat for At or ab...
# 5   Donut chart representing the stat for At or ab...
# ...
