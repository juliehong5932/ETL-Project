# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser
import pandas as pd
import os
import time
import requests

# %%
executable_path = {'executable_path': 'chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = "https://nces.ed.gov/ccd/tables/ACGR_RE_and_characteristics_2015-16.asp"
browser.visit(url)

# %%
html = browser.html

# %%
tables = pd.read_html(url)

df = tables[1]
df.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0             Unnamed: 2_level_0  \
#   Unnamed: 0_level_1 Unnamed: 1_level_1             Unnamed: 2_level_1
#                State              Total American Indian/ Alaska Native
# 0     United States2               84.1                           71.9
# 1                NaN                NaN                            NaN
# 2            Alabama               87.1                             90
# 3             Alaska               76.1                             64
# 4            Arizona               79.5                           67.7
#
#   Unnamed: 3_level_0     Unnamed: 4_level_0     Unnamed: 5_level_0  \
#   Unnamed: 3_level_1 Asian/Pacific Islander Asian/Pacific Islander
#   Unnamed: 3_level_2                  Total                 Asian1
# 0                NaN                   90.8                      —
# 1                NaN                    NaN                    NaN
# ...

# %%
new_header = ['State', 'Total', "American Indian/Alaska Native", 'NaN', 'Asian/Pacific Islander', 'Asian', 'Hawaiian Native/Pacific Islander',
             'NaN2','Hispanic', 'NaN3','Black', 'NaN4', 'White', 'NaN5', 'Two or more races', 'NaN6', 'Economically disadvantaged', 'NaN7', 
             'Limited English Proficiency', 'NaN8', 'Students with disabilities']
df.columns = new_header
df.head()
# Out:
#             State  Total American Indian/Alaska Native  NaN  \
# 0  United States2   84.1                          71.9  NaN
# 1             NaN    NaN                           NaN  NaN
# 2         Alabama   87.1                            90  NaN
# 3          Alaska   76.1                            64  NaN
# 4         Arizona   79.5                          67.7  NaN
#
#   Asian/Pacific Islander Asian Hawaiian Native/Pacific Islander  NaN2  \
# 0                   90.8     —                                —   NaN
# 1                    NaN   NaN                              NaN   NaN
# 2                     91     —                                —   NaN
# 3                     81     —                                —   NaN
# 4                     89     —                                —   NaN
#
#    Hispanic  NaN3  ...  NaN4  White  NaN5  Two or more races NaN6  \
# 0      79.3   NaN  ...   NaN   88.3   NaN                  —  NaN
# ...

# %%
df_clean = df.drop(columns = ['NaN', 'NaN2','NaN3','NaN4','NaN5','NaN6','NaN7','NaN8'])
df_clean
# Out:
#                    State  Total American Indian/Alaska Native  \
# 0         United States2   84.1                          71.9
# 1                    NaN    NaN                           NaN
# 2                Alabama   87.1                            90
# 3                 Alaska   76.1                            64
# 4                Arizona   79.5                          67.7
# 5               Arkansas   87.0                            87
# 6             California   83.0                          74.0
# 7               Colorado   78.9                            62
# 8            Connecticut   87.4                            89
# 9               Delaware   85.5                         >=90%
# 10  District of Columbia   69.2                            <>
# 11               Florida   80.7                            77
# 12               Georgia   79.4                            69
# 13                Hawaii   82.7                            72
# ...
