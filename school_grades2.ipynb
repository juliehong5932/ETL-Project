# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup as bs
from splinter import Browser
import pandas as pd
import os
import time
import requests
import numpy as np

# %%
school_grades = "school_grade.csv"

# %%
grade_df = pd.read_csv(school_grades)
grade_df
# Out:
#     school_Yer                           Race  Prekindergarden  kindergarden  \
# 0         1999                          Total              751          3397
# 1         1999                          White              354          2010
# 2         1999                          Black              181           590
# 3         1999                       Hispanic              180           627
# 4         1999         Asian/Pacific Islander               27           132
# ..         ...                            ...              ...           ...
# 65        2017                       Hispanic              439          1008
# 66        2017                          Asian               62           199
# 67        2017               Pacific Islander                3            13
# 68        2017  American Indian/Alaska Native               17            35
# 69        2017              Two or more races               59           179
#
# ...

# %%
cleaned_data = grade_df.drop(['Prekindergarden', 'kindergarden', 'first_grade', 'second_grade', 'third_grade', 'forth_grade', 'fifth_grade','sixth_grade', 'eighth_grade', 'ninth_grade','tenth_grade', 'Race'], axis=1)
cleaned_data.head(10)
# Out:
#    school_Yer  seventh_grade  eleventh_grade  twelvth_grade
# 0        1999           3541            3034           2782
# 1        1999           2243            2045           1920
# 2        1999            595             432            380
# 3        1999            522             382            321
# 4        1999            138             141            131
# 5        1999             43              33             29
# 6        2001           3720            3174           2863
# 7        2001           2282            2108           1943
# 8        2001            646             453            393
# 9        2001            593             427            354

# %%
grade_df.plot(kind='bar')

plt.title('School Grades ')

plt.xlabel('grade')

plt.ylabel('count')
#plt.figure(figsize=(20,10))
plt.legend('grade')
plt.show()
